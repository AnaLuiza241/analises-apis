# %%
import pandas as pd

# %%
sp = pd.read_csv('..\csv\DadosGeoeGold.csv')
sp = sp[sp['city'] == 'SAO PAULO']
sp.head()
# Out:
#      Unnamed: 0.3  Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0 number  \
# 783           791           203           203         203    101
# 784           792           203           203         203    101
# 785           793           203           203         203    101
# 786           794           203           203         203    101
# 787           795           204           204         204      2
#
#                  street       city   district_x  postcode    latGold  \
# 783  RUA ENRIQUE AMORIM  SAO PAULO  PARELHEIROS       NaN -23.867041
# 784  RUA ENRIQUE AMORIM  SAO PAULO  PARELHEIROS       NaN -23.867041
# 785  RUA ENRIQUE AMORIM  SAO PAULO  PARELHEIROS       NaN -23.867041
# 786  RUA ENRIQUE AMORIM  SAO PAULO  PARELHEIROS       NaN -23.867041
# 787    BENEDITO SCHUNCK  SAO PAULO     MARSILAC       NaN -23.880401
#
#        lonGold         geoapi_id  request_id        lat       long   accuracy  \
# ...

# %%
sp = sp[['number', 'street', 'city', 'latGold', 'lonGold','geoapi_id', 'request_id', 'lat', 'long', 'accuracy', 'public_place']]

sp.head()
# Out:
#     number              street       city    latGold    lonGold  \
# 783    101  RUA ENRIQUE AMORIM  SAO PAULO -23.867041 -46.753330
# 784    101  RUA ENRIQUE AMORIM  SAO PAULO -23.867041 -46.753330
# 785    101  RUA ENRIQUE AMORIM  SAO PAULO -23.867041 -46.753330
# 786    101  RUA ENRIQUE AMORIM  SAO PAULO -23.867041 -46.753330
# 787      2    BENEDITO SCHUNCK  SAO PAULO -23.880401 -46.741814
#
#             geoapi_id  request_id        lat       long   accuracy  \
# 783            Google       10194 -23.868345 -46.756709        NaN
# 784  OpenRouteService       10194 -23.866982 -46.755118   0.800000
# 785            TomTom       10194 -23.867940 -46.756150  14.117027
# 786            MapBox       10194 -23.866895 -46.753499   0.740000
# 787            TomTom       10195 -23.880390 -46.741730  11.907970
#
#            public_place
# 783  RUA ENRIQUE AMORIM
# 784  RUA ENRIQUE AMORIM
# 785  RUA ENRIQUE AMORIM
# 786  RUA ENRIQUE AMORIM
# 787    BENEDITO SCHUNCK

# %%
sp.to_csv('..\csv\baseSP.csv', index=False)

# %%
len(sp['request_id'].unique())
# Out:
# 7157

# %%
spcomp = pd.read_csv('..\csv\spComp.csv')
spcomp = spcomp[spcomp['city'] == 'SAO PAULO']
spcomp.head()
# Out:
#      Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0 number                   street  \
# 203           203           203         203    101       RUA ENRIQUE AMORIM
# 204           204           204         204      2         BENEDITO SCHUNCK
# 205           205           205         205    S/N  EST ENGENHEIRO MARCILAC
# 206           206           206         206      7          PASCOAL BELMONT
# 207           207           207         207     75     RUA FILOMENA BELMONT
#
#           city     district  postcode    latGold    lonGold
# 203  SAO PAULO  PARELHEIROS       NaN -23.867041 -46.753330
# 204  SAO PAULO     MARSILAC       NaN -23.880401 -46.741814
# 205  SAO PAULO     MARSILAC       NaN -23.875968 -46.738807
# 206  SAO PAULO     MARSILAC       NaN -23.908371 -46.707091
# 207  SAO PAULO     MARSILAC       NaN -23.907963 -46.706575

# %%
len(spcomp)
# Out:
# 7219
